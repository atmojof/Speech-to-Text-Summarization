# %%
import requests
import json
import os

# Your Hugging Face API token
API_TOKEN = os.getenv("HF_API_KEY")

MODEL_NAME = "Qwen/Qwen2.5-Coder-32B-Instruct" #"google/gemma-2-2b-it"

# The API endpoint for chat completion
API_URL = f"https://api-inference.huggingface.co/models/{MODEL_NAME}"

# Headers with your API token
headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

# Function to query the model
def query_model(prompt):
    payload = {
        "inputs": prompt,
        "parameters": {
            "max_length": 50,  # Adjust max length as needed
            "temperature": 0.7,  # Adjust temperature for creativity
            "top_p": 0.9  # Adjust top-p for nucleus sampling
        }
    }

    response = requests.post(API_URL, headers=headers, json=payload)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Example usage
if __name__ == "__main__":
    DOCUMENT_PATH = "D:/Github/Speech-to-Text-Summarization/transcription.txt"
    with open(DOCUMENT_PATH, "r", encoding="utf-8") as f:
        document_text = f.read()
    # Your input prompt
    user_prompt = "Summarise following text: " + document_text

    # Query the model
    result = query_model(user_prompt)

    if result:
        # Print the model's response
        print("Model Response:")
        print(result[0]['generated_text'])
# Out:
# Error: 422
# {"error":"Input validation error: `inputs` tokens + `max_new_tokens` must be <= 32768. Given: 127967 `inputs` tokens and 0 `max_new_tokens`","error_type":"validation"}

# %% [markdown]
# ## 2nd approach

# %%
import requests
import json
import os
from transformers import AutoTokenizer

# Your Hugging Face API token
API_TOKEN = os.getenv("HF_API_KEY")

MODEL_NAME = "Qwen/Qwen2.5-Coder-32B-Instruct"
API_URL = f"https://api-inference.huggingface.co/models/{MODEL_NAME}"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_model(prompt, max_new_tokens=500):
    payload = {
        "inputs": prompt,
        "parameters": {
            "max_new_tokens": max_new_tokens,  # Controls response length
            "temperature": 0.7,
            "top_p": 0.9
        }
    }

    response = requests.post(API_URL, headers=headers, json=payload)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

def split_document(document_text, tokenizer, max_tokens):
    # Tokenize the document without special tokens
    tokens = tokenizer.encode(document_text, add_special_tokens=False)
    
    chunks = []
    current_chunk = []
    
    for token in tokens:
        current_chunk.append(token)
        if len(current_chunk) >= max_tokens:
            chunks.append(current_chunk)
            current_chunk = []
    
    if current_chunk:
        chunks.append(current_chunk)
    
    # Decode token chunks back to text
    return [tokenizer.decode(chunk) for chunk in chunks]

if __name__ == "__main__":
    DOCUMENT_PATH = "D:/Github/Speech-to-Text-Summarization/transcription.txt"
    with open(DOCUMENT_PATH, "r", encoding="utf-8") as f:
        document_text = f.read()

    # Initialize tokenizer
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    
    # Calculate token usage for static prompt part
    static_prompt = "Summarise following text: "
    static_prompt_tokens = tokenizer.encode(static_prompt, add_special_tokens=False)
    
    # Set safety margin to account for model's internal formatting
    max_total_tokens = 32768
    max_response_tokens = 500
    available_tokens = max_total_tokens - len(static_prompt_tokens) - max_response_tokens
    
    # Split document into chunks that fit with the prompt
    document_chunks = split_document(document_text, tokenizer, available_tokens)
    
    summaries = []
    for i, chunk in enumerate(document_chunks):
        print(f"Processing chunk {i+1}/{len(document_chunks)}")
        
        # Create full prompt with your exact structure
        full_prompt = static_prompt + chunk
        
        # Verify token count
        prompt_tokens = tokenizer.encode(full_prompt, add_special_tokens=False)
        print(f"Token count: {len(prompt_tokens)} (max allowed: {max_total_tokens - max_response_tokens})")
        
        # Get summary for this chunk
        result = query_model(full_prompt, max_new_tokens=max_response_tokens)
        
        if result and isinstance(result, list) and 'generated_text' in result[0]:
            summaries.append(result[0]['generated_text'])
        else:
            summaries.append(f"[Summary failed for chunk {i+1}]")

    # Combine all summaries
    final_summary = "\n\n".join(summaries)
    
    # Save and display results
    with open("summary.txt", "w", encoding="utf-8") as f:
        f.write(final_summary)
    
    print("\nFinal Summary:")
    print(final_summary)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (127961 > 32768). Running this sequence through the model will result in indexing errors
# Processing chunk 1/4
# Token count: 32267 (max allowed: 32268)
# Processing chunk 2/4
# Token count: 32268 (max allowed: 32268)
# Processing chunk 3/4
# Token count: 32268 (max allowed: 32268)
# Processing chunk 4/4
# Token count: 31184 (max allowed: 32268)
#
# Final Summary:
# Summarise following text: Bagi banyak kasih ya malah. Jadi nomor satu masih opsi anda tetangga pak. Sorry aku boleh izin rekam ya soalnya buat buat nonton takutnya kita ada lupa aja sih sebenarnya. Saya tunggu satu masih lsy. Nomor duanya setiap tiba tiba. Kemarin sih asia timur banyak Kazakhstan sekali promonya india. Oh iya oh iya kemarin india jadi india nih lagi ramai banget di Bali. Iya sih kamu kemarin nilai biasa kita memang sama nih om ayamnya juga kan idealnya ini dia ayamnya juga kita ayamnya india ini india lagi. Amin banget datang. Kerja juga enggak nulisnya. Kita lihat data tourism nih. 3 baru china cimbo. Tempatnya. Hores selatan sama juki di situ. Jadi memang kalau bulenya ini lagi agak ini bu ya. Lagi agak menurun nampil balik lagi nanti marketnya. Sinar Mas helmy apakah memang mau main lisold atau pre old atau 2 duanya? Atau mau 2 duanya karena kalau dia. Lice hoax pasti target marketnya kan? Tanyakan beli mulai orang tua walaupun bule sekarang sudah banyak beli free hold pakai PMA. Melalui PMA dia bisa beli tripel sampai HGD. Jadi dia bikin PT oh harus sama PT mereka bikin PT boleh bolehnya bikin PT dia jadi pma karena model asing beli properti di Bali bisa sampai free hold dia lalu ada orang lokalnya di dalam. Misalkan direkturnya orang lokal, salah satu kekuatan hukum Indonesia bagian ekonomi Indonesia pt berarti ya dan dia mereka buat klik properti doang. Bisa jadi mereka memang di sini atau belum? Bisa jadi memang mereka hamil untuk. Beli properti. Karena banyak juga kan beberapa kalau yang. Yang disung enggak enaknya ya memang di lounge dipastikan banyak juga. Iya kata teman jadi kita ada teman juga kemarin ketemu katanya banyak wani launching juga di Bali sebenarnya ya makan bulan susah, kadang kadang identifikasinya ya. Terus um kalau marketnya. Kan gini pak, saya mau nanya tadi kan sebenarnya kita juga dari dari yang kita lihat. Kemarin sih kita akan rekomendasi vilanya 2 nih satu di Solo satu. Nah kalau freku kan otomatis untuk domestik. Nah sekarang untuk riskot nih resolve ini kan sebenarnya challenge challenge nya adalah kita harus bisa jualinya keluar gitu kan? Kalau yang dari kemarin kita lihat kan ada salah satunya yola tuh pak yolla itu kan dia cukup kuat ya dia dia rusia ya gitu ya kayak dia romani ya dia romania, romania, romania. Nah dia tuh cukup banyak projectnya dan bagus lah dan dia itu dari konstruksi sampai manajemen sama developer itu mereka punya semua gitu nama pinggul. Di kabel l pala. Terus apa namanya night ya? Dia bilang bahwa dia itu memang mas harinya keluar baik untuk primary maupun second tadi kalau second tadi kan untuk sewa sewanya kan gitu. Nah kalau untuk sewa oke lah gitu. Tapi untuk yang premary ini kalau kita mau this hold gitu ya challengenya begitu itu enggak sih pak? Tapi kalau. Kalau mau gini aja opsional aja. Jadi sekarang ini rata rata project itu opsional jadi gini kita jual free hold sebenarnya, tapi kan enggak menurut kemungkinan dari 10 kliennya 2 ada orang yang mereka mau beli bisa enggak kita kasih lah opsi place nah tergantung di soalnya dari kebijakannya silakan mas lain nanti mau berapa lama kan? Dulu ada cita jeansku lama banget bu ini canggih dulu citain situ 99 tahun 100 tahun lah ke dalam jadi kayak seumur hidup. Diperpanjang diperpanjang dia skemanya pasti secara administrasi perpanjang perpanjang perpanjang perpanjang 30 13. Tapi dia sudah tantangan di depan gitu loh. Sudah di depan jadi si nasabah si klien tahunya ya sudah iya saya 100 tahun itu harusnya lagi mahal yang pak harganya ya harganya dulu dia cukup tinggi, tapi dia memang enggak jualan ring karena setelah tata itu di sana susah bu hampir dikatakan hampir hampir tidak bisa hampir saya dengar ada yang bisa, tapi saya sampai sekarang belum lihat sertifikat pemerasannya masih kemarin itu juga ada yang si apa namanya yang evolit itu nama projectnya pandawa. Pondok pak kita rasanya pak kayak kalau kondom minum ini sertifikatnya apa strata title kita bilang enggak list volt dia bilang tapi e ...
#
# Summarise following text:  tiga puluh tahun harganya tetap sama dia tiga puluh plus berapa ya bu plus dua lima plus dua lima ya tiga puluh mas dua lima atau dua lima plus lima harganya harganya kalau dia sudah ngetes soalnya sama tapi ada juga kalau kata si pandawa dibilang kalau kita ngambil tiga puluh terus pada saat kita perpanjang lagi enggak ada biaya ya katanya ada enggak harganya ada juga harganya sanu sama yang harga pas dia pertama kali jadi setelah tiga puluh tahun harganya tetap sama Unitnya dia beli lagi sama sekali lagi harganya sama harganya tetap sama katanya. Tapi harga awalnya lebih murah. Belinya lebih murah karena dia list how jadi dia beli home list lebih murah dan kalau dia memperpanjang akhirnya saya sama sama awal dia beli ya harus ke 30 tahun harganya sudah naik kan ini tetap sama. unitnya dia beli lagi sama sekali lagi harganya sama harganya tetap sama katanya tapi harga awalnya lebih murah belinya lebih murah karena dia list how jadi dia beli home list lebih murah dan kalau dia memperpanjang akhirnya saya sama sama awal dia beli ya harus ke tiga puluh tahun harganya udah naik kan ini tetap sama unitnya dia beli lagi sama sekali lagi harganya sama harganya tetap sama kata tapi harga awalnya lebih murah belinya lebih murah karena dia list how jadi dia beli home list lebih murah dan kalau dia memperpanjang akhirnya saya sama sama awal dia beli ya harus ke tiga puluh tahun harganya sudah naik kan ini tetap sama dia beli lagi sama sekali lagi harganya sama harganya tetap sama katanya tapi harga awalnya lebih murah belinya lebih murah karena dia list how jadi dia beli home list lebih murah dan kalau dia memperpanjang akhirnya saya sama sama awal dia beli ya harus ke tiga puluh tahun harganya sudah naik kan ini tetap sama iya dia beli lagi sama sekali lagi harganya sama harganya tetap sama katanya tapi harga awalnya lebih murah belinya lebih murah karena dia list how jadi dia beli home list lebih murah dan kalau dia memperpanjang akhirnya saya sama sama awal dia beli ya harus ke tiga puluh tahun harganya sudah naik kan ini tetap sama Jadi bener sih kecuali tadi kalau mau harganya sama dari awal ya dia harus ambil harusnya gini kan kalau besok kan kita sewa kerja kayaknya sewa saya sewa 2000 tahun banget kamu kalau mau simaknya ke banyak lagi, tapi nilainya enggak dinaiki karena mungkin bangunannya sudah menyusut. Sebenarnya 50 tahun saya. jadi bener sih kecuali tadi kalau mau harganya sama dari awal ya dia harus ambil ibaratnya gini kan kalau besok kan kita sewa kerja kayaknya sewa saya sewa dua ribu tahun banget kamu kalau mau simaknya ke banyak lagi tapi nilainya enggak dinaiki karena mungkin bangunannya sudah menyusut sebenarnya lima puluh tahun saya jadi bener sih kecuali tadi kalau mau harganya sama dari awal ya dia harus ambil harusnya gini kan kalau besok kan kita sewa kerja sewa saya sewa dua ribu tahun banget kamu kalau mau simaknya ke banyak lagi tapi nilainya enggak dinaiki karena mungkin bangunannya sudah menyusut sebenarnya lima puluh tahun saya jadi bener sih kecuali tadi kalau mau harganya sama dari awal ya dia harus ambil ibaratnya gini kan kalau besok kan kita sewa kerja sewa saya sewa dua ribu tahun banget kamu kalau mau simaknya ke banyak lagi tapi nilainya enggak dinaiki karena mungkin bangunannya sudah menyusut sebenarnya lima puluh tahun saya jadi bener sih kecuali tadi kalau mau harganya sama dari awal ya dia harus ambil harusnya gini kan kalau besok kan kita sewa kerja kayaknya sewa saya sewa dua ribu tahun banget kamu kalau mau simaknya kalau banyak lagi tapi nilainya enggak dinaiki karena mungkin bangunannya sudah menyusut sebenarnya lima puluh tahun saya Iya betul. ya betul iya betul ini Juga ada yang pasti jemput tahu, tapi dia kayak 30 jangan puluh dan dia 80 ya kondom konsep tiup enggak mau enggak pandu kalau video video gitu jadi 30 30. juga ada yang pasti jemput tahu tapi dia kayak tiga puluh jangan puluh nah dia delapan puluh ya kondom konsep tiup enggak mau enggak pandu kala ...
#
# Summarise following text:  kayak ahok mahal banget ya untuk tabanan tapi ciputra belum lonceng lagi ya si putra itu iya belum launching lagi nih overprise soalnya dia tapi emang iya iya emang berita soalnya aja tapi kan itu juga kita juga dibilang itu kayak aku mahal banget ya untuk tabanan Nah yang beli itu rata rata investor di customer customer lamanya itu. nah yang beli itu rata rata investor di customer customer lamanya gitu nah yang beli itu rata rata investor customer customer lamanya itu nah yang beli itu rata rata investor di customer costumer lamanya itu nah yang beli itu rata rata investor customer customer lamanya gitu Si putra kan gimana aja kan ya dia kan sama lah tapi pasar sekedarnya sewanya jalan pak harusnya kalau sewa jalan karena saya banyak yang bunga juga ya bu ya nah terakhir dia jualan vila yang lumalah habis habisan yang one bedroom di atas yang kita lihat bu ya ya ya ya soalnya kosongnya masih banyak kita sekarang itu kenapa dibuat keju sedih jual kaveling dia terus. si putra kan gimana aja kan ya dia kan sama lah tapi kan tadinya sewanya jalan pak harusnya kalau sewa jalan karena saya banyak yang bunga juga ya bu ya nah terakhir dia jualan vila yang lumalah habis habisan yang one bedroom di atas yang kita lihat bu ya ya ya ya soalnya kosongnya masih banyak kita sekarang itu kenapa dibuat keju sedih jual kaveling dia terus si putra kan gimana aja kan ya dia kan sama lah tapi pasar sekedarnya sewanya jalan pak harusnya kalau sewa jalan karena saya banyak yang bunga juga ya bu ya nah terakhir dia jualan villa yang lumalah habis habisan yang one bedroom di atas yang kita lihat bu ya ya ya ya soalnya kosongnya masih banyak kita sekarang itu kenapa dibuat keju sedih jual kaveling dia terus si putra kan gimana aja kan ya dia kan sama lah tapi kan tadinya sewanya jalan pak harusnya kalau sewa jalan karena saya banyak yang bunga juga ya bu ya nah terakhir dia jualan villa yang lumalah habis habisan yang one bedroom di atas yang kita lihat bu ya ya ya ya soalnya kosongnya masih banyak kita sekarang itu kenapa dibuat keju sedih jual kaveling dia terus si putra kan gimana aja kan ya dia kan sama lah tapi pasar sekedarnya sewanya jalan pak harusnya kalau sewa jalan karena saya banyak yang bunga juga ya bu ya nah terakhir dia jualan vila yang lumalah habis habisan yang one bedroom di atas yang kita lihat bu ya ya ya ya soalnya kosongnya masih banyak kita sekarang itu kenapa dibuat keju sedih jual kaveling dia terus comfor Kan orang dia kiri kanannya masih sawah enggak ada apa apa mau makan aja bingung gimana. kan orang dia kiri kanannya masih sawah enggak ada apa apa mau makan aja bingung gimana tuh orang dia kiri kanannya masih sawah enggak ada apa apa mau makan aja bingung gimana orang dia kiri kanannya masih sawah enggak ada apa apa mau makan aja bingung gimana tuh kan orang dia kiri kanannya masih sawah enggak ada apa apa mau makan aja bingung gimana tuh kan Ngomongnya gini makanannya ini gue mau ke mana? Kayak supermarket juga bingung maksudnya kecuali balik lappingnya. ngomongnya gini makanannya ini gua mau ke mana kayak supermarket juga bingung maksudnya kecuali balik lappingnya ngomongnya gini makanya ini gue mau ke mana kayak supermarket juga bingung maksudnya kecuali balik lappingnya mau makannya gini makanannya ini gue mau ke mana kayak supermarket juga bingung maksudnya kecuali balik lappingnya ngomongnya gini makanannya ini gue mau ke mana kayak supermarket juga bingung maksudnya kecuali balikin bleepingnya Katanya, tapi mau bikin ini ya mereka ya bikin. katanya tapi mau bikin ini ya mereka ya bikin uh katanya tadi mau bikin ini ya mereka ya bikin katanya tadi mau bikin ini ya mereka ya bikin uh katanya tapi kalau bikin ini ya mereka ya bikin Ya hotel hot sebenarnya memang waktu itu nggak disebutin deh hotel bintang limanya tadinya mau apa? Terus kayaknya enggak disebutin aja nyebut nama nyebutnya nyebut brand sekarang kemarin datang udah enggak disebut enggak kemarin mari kita enggak datang lagi, kem ...
#
# Summarise following text: akangan saja maksudnya feeling saya sih ya belakangan saja maksudnya feeling saya sih ya lebih nantiin belakangan aja maksudnya Coba dibikin ini dulu aja. coba dibikinnya dulu aja coba dibikininnya dulu aja coba dibikinnya dulu aja iya coba dibikin ini dulu aja iya Pengen plan nih ya master flan ya big plannya tuh mau gimana itu dulu aja. Saya rasa kalau sebesar ini kelas ini orang kalau bagus harganya sedikit mau tetap dibeli sih. Harusnya kalau sudah jelas nih kalau segmentnya Sinar Mas sih, pengennya kayak jimbaran hijau. Pak iya cuma kan kemenalan ya maksudnya itu dia juga lambat ya ke depannya kan lambat kan. pengen plan nih ya master flan ya big plannya tuh mau gimana itu dulu aja saya rasa kalau sebesar ini kelas ini orang kalau bagus harganya sedikit mau tetap dibeli sih harusnya kalau sudah jelas nih kalau segmennya sinar mas sih pengennya kayak jimbaran hijau pak iya cuma kan kemenalan ya maksudnya itu dia juga lambat ya ke depannya kan lambat kan pengen plan nih ya master flan ya big plannya tuh mau gimana itu dulu aja saya rasa kalau sebesar ini kelas ini orang kalau bagus harganya sedikit mau tetap dibeli sih harusnya kalau sudah jelas nih kalau segmentnya sinar mas sih pengennya kayak jimbaran hijau pak iya cuma kan kemenalan ya maksudnya itu dia juga lambat ya ke depannya kan lambatnya pengen plan nih ya master flan ya big plannya tuh mau gimana itu dulu aja saya rasa kalau sebesar ini kelas ini orang kalau bagus harganya sedikit mau tetap dibeli sih harusnya kalau udah jelas nih kalau segmentnya sinar mas sih pengennya kayak jimbaran hijau pak iya cuma kan kemenalan ya maksudnya itu dia juga lambat ya ke depannya kan lambat kan pengen plan nih ya master flan ya big plannya tuh mau gimana itu dulu aja saya rasa kalau sebesar ini kelas ini orang kalau bagus harganya sedikit mau tetap dibeli sih harusnya kalau sudah jelas nih kalau segmentnya sinar mas sih pengennya kayak jimbaran hijau pak iya cuma kan kemenalan ya maksudnya itu dia juga lambat ya tujuannya kan lambat kan Jadi harusnya dikombin aja. jadi harusnya dicombine aja Samakan speed penjualan di sini ya sama dia itu beda banget. samakan speed penjualan di sini ya sama dia bali itu beda banget samakan speed penjualan di sini iya sama dia itu beda banget samakan speed penjualan di sini iya sama dia bali itu beda banget sama speed penjualan di sini ya sama dia itu beda banget Karena gini. karna gini Ibu datang kembali. Mau setelah. ibu datang kembali mau suruh ibu datang kembali mau setelnya ibu datang kembali mau setelahnya Itu belum tentu gue bisa besok mau ajak sama lu mau ajak anak belum tentu besok bisa berapa bulannya lagi itu mbak. Biarkan. itu belum tentu gue bisa besok mau ajak sama gue mau ajak anak belum tentu besok bisa berapa bulannya lagi itu mbak biarkan itu belum tentu gue bisa besok mau ajak sama lu mau ajak anak belum tentu besok pisah berapa bulannya lagi itu mbak biarkan itu belum tentu gue bisa besok mau ajak sama gue mau ajak anak belum tentu besok pisah berapa bulannya lagi itu mbak biarkan itu belum tentu gue bisa besok mau ajak sama lu mau ajak anak belum tentu besok bisa berapa bulannya lagi tuh mbak biarkan Pun sebaliknya nembak ke Jakarta ibarat atau ke Bandung di mana kan datangnya nanti misalkan dia boleh Agustus berapa Desember? pun sebaliknya nembak ke jakarta ibarat atau ke bandung di mana kan datangnya nanti misalkan dia boleh agustus berarti desember pun sebaliknya nembak ke jakarta ibarat atau kebangun kan datangnya nanti misalkan dia boleh agustus berapa desember pun sebaliknya nembak ke jakarta imbuh atau kebangun kan datangnya nanti misalkan dia boleh agustus berapa desember pun sebaliknya nembak ke jakarta ibarat atau ke bali mana kan datangnya nanti misalkan dia boleh agustus berapa desember Kecuali dia memang tipikalnya bolak balik bolak balik dan dia mau untuk mode biasa. Saya beli bikinkan saja bisa kemarin silih saya ngomong gitu dia kan di sini. Aduh bu katanya harus sabar katanya. Soaln ...
